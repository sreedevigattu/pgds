# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df = pd.read_csv("data/bikesharing.csv")
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Review:
# There were multiple requests for the links. Instructor kept sharing thehm. Flow is interrupted. Time is wasted. Can the messages from instructor be pinned?
# Instructor should explain the concept and then take the questions. This way the flow of explanation is not interrupted. Maybe some of the simple questions are ansered during the explanation.
# Students continuously ask questions (valid, invalid, repeated, simple).

# %% [markdown]
# # Problem statement
# Aanlyse the demand. Target variable: cnt

# %%
sns.displot(df['windspeed']);plt.show()

# %%
#sns.set_style('default')
# density

# %%
sns.histplot(df['windspeed']);plt.show()

# %%
sns.distplot(df['hum']);plt.show()
# Out:
# /Users/sreedevigattu/sree/PGDS/PreparatoryCourse/python/venv/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['windspeed'].describe(percentiles=[0.25,0.5,0.75,.98,1])
# Out:
# count    730.000000
# mean      12.763620
# std        5.195841
# min        1.500244
# 25%        9.041650
# 50%       12.125325
# 75%       15.625589
# 98%       25.201627
# 100%      34.000021
# max       34.000021
# Name: windspeed, dtype: float64

# %%
sns.boxplot(df['windspeed']);plt.show()
# Out:
# /Users/sreedevigattu/sree/PGDS/PreparatoryCourse/python/venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['yr'], df['windspeed']);plt.show()
# Out:
# /Users/sreedevigattu/sree/PGDS/PreparatoryCourse/python/venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['mnth'], df['cnt']);plt.show()
# Out:
# /Users/sreedevigattu/sree/PGDS/PreparatoryCourse/python/venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
